# %% [markdown]
# # <center>World Map Geovisualization using Folium and Covid Data

# %% [markdown]
# ### <center>Instructor: Vinita Silaparasetty

# %% [markdown]
# ### Import Libraries

# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Generate Base Map

# %% [markdown]
# ### Access Data via API

# %%
conn= http.client.HTTPSConnection("api.covid19api.com")
payload=''
headers={}
conn.request("GET", "/summary",payload,headers)
res=conn.getresponse()
data=res.read().decode('UTF-8')

# %% [markdown]
# ### Convert Data to JSON

# %%
covid19=json.loads(data)

# %% [markdown]
# ### Normalize Data

# %%
pd.json_normalize(covid19['Countries'], sep=",")
# Out:
#                                        ID                          Country  \
# 0    176c32d8-3fa8-427e-805b-594b8070dd65                      Afghanistan
# 1    fc483202-fe3d-4ba4-9c42-494673af804c                          Albania
# 2    96935f3a-2427-4b76-b550-bf49695e6e0a                          Algeria
# 3    335c787f-058a-4bfd-9912-1548ef0fadb3                          Andorra
# 4    c4372d98-af8b-47ed-ac6e-b5a4a91839fc                           Angola
# ..                                    ...                              ...
# 185  2b6c5efd-a473-4525-ab4e-85de56d4beee  Venezuela (Bolivarian Republic)
# 186  cedcc5d8-0f6f-41bf-90c3-97b76a7bb84b                         Viet Nam
# 187  bcab648e-778b-479a-bc0e-ce57e292b27e                            Yemen
# 188  d7d6d5e1-e123-42d1-b276-2116065e1d52                           Zambia
# 189  f35d82bd-1058-4ffe-8efa-6cd828c26bcb                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan             0           55917          0
# 1            AL      albania             0          115442          0
# 2            DZ      algeria             0          114851          0
# 3            AD      andorra             0           11130          0
# 4            AO       angola             0           21205          0
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          144277          0
# 186          VN      vietnam             0            2533          0
# 187          YE        yemen             0            2667          0
# 188          ZM       zambia             0           83913          0
# 189          ZW     zimbabwe             0           36377          0
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0           2451             0           49499  2021-03-12T07:23:15.671Z
# 1           2002             0           78259  2021-03-12T07:23:15.671Z
# 2           3028             0           79556  2021-03-12T07:23:15.671Z
# 3            112             0           10708  2021-03-12T07:23:15.671Z
# 4            517             0           19827  2021-03-12T07:23:15.671Z
# ..           ...           ...             ...                       ...
# 185         1415             0          136269  2021-03-12T07:23:15.671Z
# 186           35             0            2048  2021-03-12T07:23:15.671Z
# 187          667             0            1464  2021-03-12T07:23:15.671Z
# 188         1148             0           80027  2021-03-12T07:23:15.671Z
# 189         1492             0           33972  2021-03-12T07:23:15.671Z
#
# [190 rows x 11 columns]

# %% [markdown]
# ### Convert to Pandas DataFrame

# %%
df=pd.DataFrame(covid19['Countries'])
df
# Out:
#                                        ID                          Country  \
# 0    176c32d8-3fa8-427e-805b-594b8070dd65                      Afghanistan
# 1    fc483202-fe3d-4ba4-9c42-494673af804c                          Albania
# 2    96935f3a-2427-4b76-b550-bf49695e6e0a                          Algeria
# 3    335c787f-058a-4bfd-9912-1548ef0fadb3                          Andorra
# 4    c4372d98-af8b-47ed-ac6e-b5a4a91839fc                           Angola
# ..                                    ...                              ...
# 185  2b6c5efd-a473-4525-ab4e-85de56d4beee  Venezuela (Bolivarian Republic)
# 186  cedcc5d8-0f6f-41bf-90c3-97b76a7bb84b                         Viet Nam
# 187  bcab648e-778b-479a-bc0e-ce57e292b27e                            Yemen
# 188  d7d6d5e1-e123-42d1-b276-2116065e1d52                           Zambia
# 189  f35d82bd-1058-4ffe-8efa-6cd828c26bcb                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan             0           55917          0
# 1            AL      albania             0          115442          0
# 2            DZ      algeria             0          114851          0
# 3            AD      andorra             0           11130          0
# 4            AO       angola             0           21205          0
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          144277          0
# 186          VN      vietnam             0            2533          0
# 187          YE        yemen             0            2667          0
# 188          ZM       zambia             0           83913          0
# 189          ZW     zimbabwe             0           36377          0
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date  \
# 0           2451             0           49499  2021-03-12T07:23:15.671Z
# 1           2002             0           78259  2021-03-12T07:23:15.671Z
# 2           3028             0           79556  2021-03-12T07:23:15.671Z
# 3            112             0           10708  2021-03-12T07:23:15.671Z
# 4            517             0           19827  2021-03-12T07:23:15.671Z
# ..           ...           ...             ...                       ...
# 185         1415             0          136269  2021-03-12T07:23:15.671Z
# 186           35             0            2048  2021-03-12T07:23:15.671Z
# 187          667             0            1464  2021-03-12T07:23:15.671Z
# 188         1148             0           80027  2021-03-12T07:23:15.671Z
# 189         1492             0           33972  2021-03-12T07:23:15.671Z
#
#     Premium
# 0        {}
# 1        {}
# 2        {}
# 3        {}
# 4        {}
# ..      ...
# 185      {}
# 186      {}
# 187      {}
# 188      {}
# 189      {}
#
# [190 rows x 12 columns]

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
covid19_2=df.drop(columns=['CountryCode', 'Slug', 'Date', 'Premium'], axis=1)
covid19_2
# Out:
#                                        ID                          Country  \
# 0    176c32d8-3fa8-427e-805b-594b8070dd65                      Afghanistan
# 1    fc483202-fe3d-4ba4-9c42-494673af804c                          Albania
# 2    96935f3a-2427-4b76-b550-bf49695e6e0a                          Algeria
# 3    335c787f-058a-4bfd-9912-1548ef0fadb3                          Andorra
# 4    c4372d98-af8b-47ed-ac6e-b5a4a91839fc                           Angola
# ..                                    ...                              ...
# 185  2b6c5efd-a473-4525-ab4e-85de56d4beee  Venezuela (Bolivarian Republic)
# 186  cedcc5d8-0f6f-41bf-90c3-97b76a7bb84b                         Viet Nam
# 187  bcab648e-778b-479a-bc0e-ce57e292b27e                            Yemen
# 188  d7d6d5e1-e123-42d1-b276-2116065e1d52                           Zambia
# 189  f35d82bd-1058-4ffe-8efa-6cd828c26bcb                         Zimbabwe
#
#      NewConfirmed  TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  \
# 0               0           55917          0         2451             0
# 1               0          115442          0         2002             0
# 2               0          114851          0         3028             0
# 3               0           11130          0          112             0
# 4               0           21205          0          517             0
# ..            ...             ...        ...          ...           ...
# 185             0          144277          0         1415             0
# 186             0            2533          0           35             0
# 187             0            2667          0          667             0
# 188             0           83913          0         1148             0
# 189             0           36377          0         1492             0
#
#      TotalRecovered
# 0             49499
# 1             78259
# 2             79556
# 3             10708
# 4             19827
# ..              ...
# 185          136269
# 186            2048
# 187            1464
# 188           80027
# 189           33972
#
# [190 rows x 8 columns]

# %% [markdown]
# ### Generate Base Map

# %%
m=folium.Map(tiles='Stamen Terrain', min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Geodata
#
# geodata url: https://raw.githubusercontent.com/python-visualization/folium/master/examples/data
#
# geo data file: world-countries.json

# %%
url='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes=f'{url}/world-countries.json'

# %% [markdown]
# ### Generate Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='Covid-19',
    data=covid19_2,
    columns=['Country', 'TotalConfirmed'],
    key_on ='feature.properties.name',
    fill_colors='OrRd',
    nan_fill_color='black',
    legend_name="Total Confirmed Covid Cases",
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Markers

# %%
covid19_2.update(covid19_2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid19_2.update(covid19_2['TotalRecovered'].map('Total Recoverd:{}'.format))

# %% [markdown]
# coordinates of countries: https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv

# %%
coordinates=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final=pd.merge(covid19_2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude], 
                       radius=5,
                       weight=2,
                       popup=[point.Country, point.TotalConfirmed, point.TotalRecovered],
                       fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot, axis=1)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Base Map

# %%
m1= folium.Map(tiles='StamenToner', min_zoom=2)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Heat Map Layer

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %%
m1.add_child(HeatMap(zip(lat, lon,deaths), radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Circular Marker

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                        radius=5,
                        weight=2,
                        popup=[point.Country,point.TotalDeaths],
                        fill_color='#000000').add_to(m1)
covid_final.apply(plotDot,axis=1)
m1.fit_bounds(m1.get_bounds())
m1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-64cbb30b29cc> in <module>
#       5                         popup=[point.Country,point.TotalDeaths],
#       6                         fill_color='#000000').add_to(m1)
# ----> 7 covid_final.apply(plotDot,axis=1)
#       8 m1.fit_bounds(m1.get_bounds())
#       9 m1
#
# NameError: name 'covid_final' is not defined
